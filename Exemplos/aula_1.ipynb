# %% [markdown]
# # Projeto 1 - Backtest modelo de investimento Magic Formula.
#
#
# ### Desafio:
#
# * Testar se a regra de investimento da fórmula mágica, do Joel Grenblatt, funcionou no Brasil nos últimos anos.
#
#
# ### Passo a passo:
#
#    **Passo 1** - Importar os módulos e bibliotecas.
#
#    **Passo 2** - Baixar os dados disponibilizados.
#
#    **Passo 3** - Calcular os retornos mensais das empresas
#
#    **Passo 4** - Filtrar  a liquidez.
#
#    **Passo 5** - Criar o ranking dos indicadores.
#
#    **Passo 6** - Criar as carteiras.
#
#    **Passo 7** - Calcular a rentabilidade por carteira.
#
#    **Passo 8** - Calcular a rentabilidade do modelo.
#
#    **Passo 9** - Calcular a rentabilidade do ibovespa no mesmo período.
#
#
#    ##### **Passo 10** - Analisar os resultados.
#
# -------------------

# %% [markdown]
# # Passo 1: Importando os módulos necessários

# %%
# %pip install quantstats
# Out:
# Collecting quantstats
#   Downloading quantstats-0.0.64-py2.py3-none-any.whl.metadata (9.3 kB)
# Collecting pandas<3.0.0,>=1.5.0 (from quantstats)
#   Downloading pandas-2.3.1-cp311-cp311-win_amd64.whl.metadata (19 kB)
# Collecting numpy<2.0.0,>=1.21.0 (from quantstats)
#   Downloading numpy-1.26.4-cp311-cp311-win_amd64.whl.metadata (61 kB)
#      ---------------------------------------- 0.0/61.0 kB ? eta -:--:--
#      ------------------- ------------------ 30.7/61.0 kB 660.6 kB/s eta 0:00:01
#      -------------------------------------- 61.0/61.0 kB 819.4 kB/s eta 0:00:00
# Collecting seaborn>=0.11.0 (from quantstats)
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting matplotlib>=3.3.0 (from quantstats)
#   Downloading matplotlib-3.10.3-cp311-cp311-win_amd64.whl.metadata (11 kB)
# Collecting scipy>=1.7.0 (from quantstats)
#   Downloading scipy-1.16.0-cp311-cp311-win_amd64.whl.metadata (60 kB)
#      ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#      ---------------------------------------- 60.8/60.8 kB 3.2 MB/s eta 0:00:00
# Collecting tabulate>=0.8.9 (from quantstats)
#   Downloading tabulate-0.9.0-py3-none-any.whl.metadata (34 kB)
# Collecting yfinance>=0.2.65 (from quantstats)
#   Downloading yfinance-0.2.65-py2.py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.8.0 in c:\users\adm\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from quantstats) (2.9.0.post0)
# Requirement already satisfied: packaging>=20.0 in c:\users\adm\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from quantstats) (25.0)
# Collecting contourpy>=1.0.1 (from matplotlib>=3.3.0->quantstats)
#   Downloading contourpy-1.3.2-cp311-cp311-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib>=3.3.0->quantstats)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib>=3.3.0->quantstats)
#   Downloading fonttools-4.59.0-cp311-cp311-win_amd64.whl.metadata (110 kB)
#      ---------------------------------------- 0.0/110.1 kB ? eta -:--:--
#      -------------------------------------- 110.1/110.1 kB 6.2 MB/s eta 0:00:00
# Collecting kiwisolver>=1.3.1 (from matplotlib>=3.3.0->quantstats)
#   Downloading kiwisolver-1.4.8-cp311-cp311-win_amd64.whl.metadata (6.3 kB)
# Collecting pillow>=8 (from matplotlib>=3.3.0->quantstats)
#   Downloading pillow-11.3.0-cp311-cp311-win_amd64.whl.metadata (9.2 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib>=3.3.0->quantstats)
#   Downloading pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# Collecting pytz>=2020.1 (from pandas<3.0.0,>=1.5.0->quantstats)
#   Downloading pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas<3.0.0,>=1.5.0->quantstats)
#   Downloading tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in c:\users\adm\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.8.0->quantstats) (1.17.0)
# Collecting requests>=2.31 (from yfinance>=0.2.65->quantstats)
#   Downloading requests-2.32.4-py3-none-any.whl.metadata (4.9 kB)
# Collecting multitasking>=0.0.7 (from yfinance>=0.2.65->quantstats)
#   Downloading multitasking-0.0.11-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\adm\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from yfinance>=0.2.65->quantstats) (4.3.8)
# Collecting frozendict>=2.3.4 (from yfinance>=0.2.65->quantstats)
#   Downloading frozendict-2.4.6-py311-none-any.whl.metadata (23 kB)
# Collecting peewee>=3.16.2 (from yfinance>=0.2.65->quantstats)
#   Downloading peewee-3.18.2.tar.gz (949 kB)
#      ---------------------------------------- 0.0/949.2 kB ? eta -:--:--
#      -------------- ----------------------- 358.4/949.2 kB 7.6 MB/s eta 0:00:01
#      ------------------------------ ------- 768.0/949.2 kB 8.1 MB/s eta 0:00:01
#      -------------------------------------- 949.2/949.2 kB 7.5 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting beautifulsoup4>=4.11.1 (from yfinance>=0.2.65->quantstats)
#   Downloading beautifulsoup4-4.13.4-py3-none-any.whl.metadata (3.8 kB)
# Collecting curl_cffi>=0.7 (from yfinance>=0.2.65->quantstats)
#   Downloading curl_cffi-0.12.0-cp39-abi3-win_amd64.whl.metadata (15 kB)
# Collecting protobuf>=3.19.0 (from yfinance>=0.2.65->quantstats)
#   Downloading protobuf-6.31.1-cp310-abi3-win_amd64.whl.metadata (593 bytes)
# Collecting websockets>=13.0 (from yfinance>=0.2.65->quantstats)
#   Downloading websockets-15.0.1-cp311-cp311-win_amd64.whl.metadata (7.0 kB)
# Collecting soupsieve>1.2 (from beautifulsoup4>=4.11.1->yfinance>=0.2.65->quantstats)
#   Downloading soupsieve-2.7-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\adm\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from beautifulsoup4>=4.11.1->yfinance>=0.2.65->quantstats) (4.14.1)
# Collecting cffi>=1.12.0 (from curl_cffi>=0.7->yfinance>=0.2.65->quantstats)
#   Downloading cffi-1.17.1-cp311-cp311-win_amd64.whl.metadata (1.6 kB)
# Collecting certifi>=2024.2.2 (from curl_cffi>=0.7->yfinance>=0.2.65->quantstats)
#   Downloading certifi-2025.7.14-py3-none-any.whl.metadata (2.4 kB)
# Collecting charset_normalizer<4,>=2 (from requests>=2.31->yfinance>=0.2.65->quantstats)
#   Downloading charset_normalizer-3.4.2-cp311-cp311-win_amd64.whl.metadata (36 kB)
# Collecting idna<4,>=2.5 (from requests>=2.31->yfinance>=0.2.65->quantstats)
#   Downloading idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting urllib3<3,>=1.21.1 (from requests>=2.31->yfinance>=0.2.65->quantstats)
#   Downloading urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting pycparser (from cffi>=1.12.0->curl_cffi>=0.7->yfinance>=0.2.65->quantstats)
#   Downloading pycparser-2.22-py3-none-any.whl.metadata (943 bytes)
# Downloading quantstats-0.0.64-py2.py3-none-any.whl (78 kB)
#    ---------------------------------------- 0.0/78.7 kB ? eta -:--:--
#    ---------------------------------------- 78.7/78.7 kB 4.3 MB/s eta 0:00:00
# Downloading matplotlib-3.10.3-cp311-cp311-win_amd64.whl (8.1 MB)
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.1 MB 9.6 MB/s eta 0:00:01
#    --- ------------------------------------ 0.8/8.1 MB 9.7 MB/s eta 0:00:01
#    ----- ---------------------------------- 1.1/8.1 MB 10.1 MB/s eta 0:00:01
#    -------- ------------------------------- 1.6/8.1 MB 10.3 MB/s eta 0:00:01
#    ----------- ---------------------------- 2.2/8.1 MB 10.9 MB/s eta 0:00:01
#    -------------- ------------------------- 2.8/8.1 MB 11.3 MB/s eta 0:00:01
#    --------------- ------------------------ 3.2/8.1 MB 10.9 MB/s eta 0:00:01
#    ------------------- -------------------- 3.9/8.1 MB 11.3 MB/s eta 0:00:01
#    ---------------------- ----------------- 4.5/8.1 MB 12.0 MB/s eta 0:00:01
#    ------------------------- -------------- 5.2/8.1 MB 12.2 MB/s eta 0:00:01
#    ----------------------------- ---------- 5.9/8.1 MB 12.6 MB/s eta 0:00:01
#    -------------------------------- ------- 6.6/8.1 MB 13.1 MB/s eta 0:00:01
#    ------------------------------------ --- 7.4/8.1 MB 13.2 MB/s eta 0:00:01
#    ---------------------------------------  8.1/8.1 MB 13.6 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 12.9 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp311-cp311-win_amd64.whl (15.8 MB)
#    ---------------------------------------- 0.0/15.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.8/15.8 MB 26.2 MB/s eta 0:00:01
#    ---- ----------------------------------- 1.6/15.8 MB 25.2 MB/s eta 0:00:01
#    ------ --------------------------------- 2.5/15.8 MB 22.6 MB/s eta 0:00:01
#    -------- ------------------------------- 3.3/15.8 MB 23.3 MB/s eta 0:00:01
#    ---------- ----------------------------- 4.1/15.8 MB 21.9 MB/s eta 0:00:01
#    ------------- -------------------------- 5.5/15.8 MB 23.2 MB/s eta 0:00:01
#    ---------------- ----------------------- 6.6/15.8 MB 23.3 MB/s eta 0:00:01
#    ------------------- -------------------- 7.7/15.8 MB 23.3 MB/s eta 0:00:01
#    ---------------------- ----------------- 8.8/15.8 MB 24.3 MB/s eta 0:00:01
#    ------------------------- -------------- 10.1/15.8 MB 24.9 MB/s eta 0:00:01
#    ----------------------------- ---------- 11.5/15.8 MB 25.1 MB/s eta 0:00:01
#    -------------------------------- ------- 12.9/15.8 MB 27.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 14.0/15.8 MB 27.3 MB/s eta 0:00:01
#    -------------------------------------- - 15.2/15.8 MB 27.3 MB/s eta 0:00:01
#    ---------------------------------------  15.8/15.8 MB 27.3 MB/s eta 0:00:01
#    ---------------------------------------- 15.8/15.8 MB 24.2 MB/s eta 0:00:00
# Downloading pandas-2.3.1-cp311-cp311-win_amd64.whl (11.3 MB)
#    ---------------------------------------- 0.0/11.3 MB ? eta -:--:--
#    ---- ----------------------------------- 1.4/11.3 MB 30.5 MB/s eta 0:00:01
#    ---------- ----------------------------- 2.9/11.3 MB 30.9 MB/s eta 0:00:01
#    --------------- ------------------------ 4.5/11.3 MB 28.6 MB/s eta 0:00:01
#    ------------------- -------------------- 5.6/11.3 MB 30.0 MB/s eta 0:00:01
#    ------------------------ --------------- 6.8/11.3 MB 29.1 MB/s eta 0:00:01
#    ----------------------------- ---------- 8.3/11.3 MB 29.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 9.9/11.3 MB 30.1 MB/s eta 0:00:01
#    ---------------------------------------  11.1/11.3 MB 31.2 MB/s eta 0:00:01
#    ---------------------------------------  11.3/11.3 MB 31.1 MB/s eta 0:00:01
#    ---------------------------------------- 11.3/11.3 MB 28.4 MB/s eta 0:00:00
# Downloading scipy-1.16.0-cp311-cp311-win_amd64.whl (38.6 MB)
#    ---------------------------------------- 0.0/38.6 MB ? eta -:--:--
#     --------------------------------------- 0.9/38.6 MB 19.8 MB/s eta 0:00:02
#    - -------------------------------------- 1.5/38.6 MB 15.7 MB/s eta 0:00:03
#    -- ------------------------------------- 2.3/38.6 MB 18.7 MB/s eta 0:00:02
#    ---- ----------------------------------- 4.1/38.6 MB 23.5 MB/s eta 0:00:02
#    ----- ---------------------------------- 5.7/38.6 MB 25.9 MB/s eta 0:00:02
#    ------- -------------------------------- 7.0/38.6 MB 27.9 MB/s eta 0:00:02
#    -------- ------------------------------- 8.3/38.6 MB 27.8 MB/s eta 0:00:02
#    ---------- ----------------------------- 10.3/38.6 MB 29.8 MB/s eta 0:00:01
#    ------------ --------------------------- 12.1/38.6 MB 36.4 MB/s eta 0:00:01
#    ------------- -------------------------- 13.4/38.6 MB 38.5 MB/s eta 0:00:01
#    -------------- ------------------------- 14.0/38.6 MB 34.6 MB/s eta 0:00:01
#    ---------------- ----------------------- 15.8/38.6 MB 34.4 MB/s eta 0:00:01
#    ----------------- ---------------------- 17.3/38.6 MB 32.8 MB/s eta 0:00:01
#    ------------------- -------------------- 19.0/38.6 MB 34.4 MB/s eta 0:00:01
#    --------------------- ------------------ 20.7/38.6 MB 34.4 MB/s eta 0:00:01
#    ----------------------- ---------------- 22.2/38.6 MB 34.4 MB/s eta 0:00:01
#    ------------------------ --------------- 24.0/38.6 MB 36.4 MB/s eta 0:00:01
#    -------------------------- ------------- 25.9/38.6 MB 38.5 MB/s eta 0:00:01
#    ----------------------------- ---------- 28.0/38.6 MB 40.9 MB/s eta 0:00:01
#    ------------------------------- -------- 29.9/38.6 MB 40.9 MB/s eta 0:00:01
#    --------------------------------- ------ 31.9/38.6 MB 38.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 33.5/38.6 MB 40.9 MB/s eta 0:00:01
#    ------------------------------------ --- 35.4/38.6 MB 38.5 MB/s eta 0:00:01
#    -------------------------------------- - 37.1/38.6 MB 40.9 MB/s eta 0:00:01
#    ---------------------------------------  38.6/38.6 MB 38.5 MB/s eta 0:00:01
#    ---------------------------------------  38.6/38.6 MB 38.5 MB/s eta 0:00:01
#    ---------------------------------------  38.6/38.6 MB 38.5 MB/s eta 0:00:01
#    ---------------------------------------- 38.6/38.6 MB 28.4 MB/s eta 0:00:00
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
#    ---------------------------------------- 0.0/294.9 kB ? eta -:--:--
#    ---------------------------------------- 294.9/294.9 kB 9.2 MB/s eta 0:00:00
# Downloading tabulate-0.9.0-py3-none-any.whl (35 kB)
# Downloading yfinance-0.2.65-py2.py3-none-any.whl (119 kB)
#    ---------------------------------------- 0.0/119.4 kB ? eta -:--:--
#    ---------------------------------------- 119.4/119.4 kB 6.8 MB/s eta 0:00:00
# Downloading beautifulsoup4-4.13.4-py3-none-any.whl (187 kB)
#    ---------------------------------------- 0.0/187.3 kB ? eta -:--:--
#    --------------------------------------- 187.3/187.3 kB 11.1 MB/s eta 0:00:00
# Downloading contourpy-1.3.2-cp311-cp311-win_amd64.whl (222 kB)
#    ---------------------------------------- 0.0/222.0 kB ? eta -:--:--
#    --------------------------------------- 222.0/222.0 kB 14.1 MB/s eta 0:00:00
# Downloading curl_cffi-0.12.0-cp39-abi3-win_amd64.whl (1.6 MB)
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ---------------------------------------  1.6/1.6 MB 49.9 MB/s eta 0:00:01
#    ---------------------------------------- 1.6/1.6 MB 34.1 MB/s eta 0:00:00
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.59.0-cp311-cp311-win_amd64.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------- ----------------- 1.3/2.3 MB 41.3 MB/s eta 0:00:01
#    ---------------------------------------  2.3/2.3 MB 36.2 MB/s eta 0:00:01
#    ---------------------------------------- 2.3/2.3 MB 28.9 MB/s eta 0:00:00
# Downloading frozendict-2.4.6-py311-none-any.whl (16 kB)
# Downloading kiwisolver-1.4.8-cp311-cp311-win_amd64.whl (71 kB)
#    ---------------------------------------- 0.0/72.0 kB ? eta -:--:--
#    ---------------------------------------- 72.0/72.0 kB ? eta 0:00:00
# Downloading multitasking-0.0.11-py3-none-any.whl (8.5 kB)
# Downloading pillow-11.3.0-cp311-cp311-win_amd64.whl (7.0 MB)
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    -------- ------------------------------- 1.4/7.0 MB 30.1 MB/s eta 0:00:01
#    ---------------- ----------------------- 2.9/7.0 MB 37.2 MB/s eta 0:00:01
#    -------------------------- ------------- 4.6/7.0 MB 36.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 6.1/7.0 MB 35.6 MB/s eta 0:00:01
#    ---------------------------------------  7.0/7.0 MB 37.1 MB/s eta 0:00:01
#    ---------------------------------------- 7.0/7.0 MB 31.9 MB/s eta 0:00:00
# Downloading protobuf-6.31.1-cp310-abi3-win_amd64.whl (435 kB)
#    ---------------------------------------- 0.0/435.3 kB ? eta -:--:--
#    --------------------------------------- 435.3/435.3 kB 13.7 MB/s eta 0:00:00
# Downloading pyparsing-3.2.3-py3-none-any.whl (111 kB)
#    ---------------------------------------- 0.0/111.1 kB ? eta -:--:--
#    ---------------------------------------- 111.1/111.1 kB 3.2 MB/s eta 0:00:00
# Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
#    ---------------------------------------- 0.0/509.2 kB ? eta -:--:--
#    --------------------------------------- 509.2/509.2 kB 16.1 MB/s eta 0:00:00
# Downloading requests-2.32.4-py3-none-any.whl (64 kB)
#    ---------------------------------------- 0.0/64.8 kB ? eta -:--:--
#    ---------------------------------------- 64.8/64.8 kB 3.4 MB/s eta 0:00:00
# Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
#    ---------------------------------------- 0.0/347.8 kB ? eta -:--:--
#    --------------------------------------- 347.8/347.8 kB 10.9 MB/s eta 0:00:00
# Downloading websockets-15.0.1-cp311-cp311-win_amd64.whl (176 kB)
#    ---------------------------------------- 0.0/176.8 kB ? eta -:--:--
#    --------------------------------------- 176.8/176.8 kB 10.4 MB/s eta 0:00:00
# Downloading certifi-2025.7.14-py3-none-any.whl (162 kB)
#    ---------------------------------------- 0.0/162.7 kB ? eta -:--:--
#    ---------------------------------------- 162.7/162.7 kB 4.9 MB/s eta 0:00:00
# Downloading cffi-1.17.1-cp311-cp311-win_amd64.whl (181 kB)
#    ---------------------------------------- 0.0/181.4 kB ? eta -:--:--
#    --------------------------------------- 181.4/181.4 kB 10.7 MB/s eta 0:00:00
# Downloading charset_normalizer-3.4.2-cp311-cp311-win_amd64.whl (105 kB)
#    ---------------------------------------- 0.0/105.4 kB ? eta -:--:--
#    ---------------------------------------- 105.4/105.4 kB 5.9 MB/s eta 0:00:00
# Downloading idna-3.10-py3-none-any.whl (70 kB)
#    ---------------------------------------- 0.0/70.4 kB ? eta -:--:--
#    ---------------------------------------- 70.4/70.4 kB 3.8 MB/s eta 0:00:00
# Downloading soupsieve-2.7-py3-none-any.whl (36 kB)
# Downloading urllib3-2.5.0-py3-none-any.whl (129 kB)
#    ---------------------------------------- 0.0/129.8 kB ? eta -:--:--
#    ---------------------------------------- 129.8/129.8 kB 3.9 MB/s eta 0:00:00
# Downloading pycparser-2.22-py3-none-any.whl (117 kB)
#    ---------------------------------------- 0.0/117.6 kB ? eta -:--:--
#    ---------------------------------------- 117.6/117.6 kB ? eta 0:00:00
# Building wheels for collected packages: peewee
#   Building wheel for peewee (pyproject.toml): started
#   Building wheel for peewee (pyproject.toml): finished with status 'done'
#   Created wheel for peewee: filename=peewee-3.18.2-py3-none-any.whl size=139153 sha256=2223b05d4ccd58c439c13a9d95fc69a85c8825bcca8d31761675fcbbc1a69b9b
#   Stored in directory: c:\users\adm\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local\pip\cache\wheels\28\84\61\758d1bd7b9c9d700158c8642a8aff2a9bf2e1ae69641c40784
# Successfully built peewee
# Installing collected packages: pytz, peewee, multitasking, websockets, urllib3, tzdata, tabulate, soupsieve, pyparsing, pycparser, protobuf, pillow, numpy, kiwisolver, idna, frozendict, fonttools, cycler, charset_normalizer, certifi, scipy, requests, pandas, contourpy, cffi, beautifulsoup4, matplotlib, curl_cffi, yfinance, seaborn, quantstats
# Successfully installed beautifulsoup4-4.13.4 certifi-2025.7.14 cffi-1.17.1 charset_normalizer-3.4.2 contourpy-1.3.2 curl_cffi-0.12.0 cycler-0.12.1 fonttools-4.59.0 frozendict-2.4.6 idna-3.10 kiwisolver-1.4.8 matplotlib-3.10.3 multitasking-0.0.11 numpy-1.26.4 pandas-2.3.1 peewee-3.18.2 pillow-11.3.0 protobuf-6.31.1 pycparser-2.22 pyparsing-3.2.3 pytz-2025.2 quantstats-0.0.64 requests-2.32.4 scipy-1.16.0 seaborn-0.13.2 soupsieve-2.7 tabulate-0.9.0 tzdata-2025.2 urllib3-2.5.0 websockets-15.0.1 yfinance-0.2.65
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: C:\Users\adm\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import quantstats as qs

# %% [markdown]
# # Passo 2: Baixar os dados dispobinilizados.

# %%
dados_empresas = pd.read_csv("dados_empresas.csv")

# %% [markdown]
# # Passo 3: Calcular os retornos mensais das empresas.

# %%
dados_empresas['retorno'] = dados_empresas.groupby('ticker')['preco_fechamento_ajustado'].pct_change()
dados_empresas['retorno'] = dados_empresas.groupby('ticker')['retorno'].shift(-1)

# %% [markdown]
# # Passo 4: Filtrar a liquidez.

# %%
dados_empresas = dados_empresas[dados_empresas['volume_negociado'] > 1000000]

# %% [markdown]
# # Passo 5: Criar o ranking dos indicadores.

# %%
dados_empresas['ranking_ev_ebit'] = dados_empresas.groupby('data')['ebit_ev'].rank(ascending = False)
dados_empresas['ranking_roic'] = dados_empresas.groupby('data')['roic'].rank(ascending = False)

dados_empresas['ranking_final'] = dados_empresas['ranking_ev_ebit'] + dados_empresas['ranking_roic']
dados_empresas['ranking_final'] = dados_empresas.groupby('data')['ranking_final'].rank()

# %%
dados_empresas[dados_empresas['data'] == '2017-06-30'].sort_values('ranking_final').head(20)
# Out:
#              data  ticker  preco_fechamento_ajustado  volume_negociado  \
# 46656  2017-06-30   TRPL4                       9.03        17445326.0
# 5114   2017-06-30   BRKM5                      26.37        52655453.0
# 16577  2017-06-30   ELET6                      12.31        22895921.0
# 16299  2017-06-30   ELET3                      10.43        48245708.0
# 9262   2017-06-30   CGAS5                      21.40         1618220.0
# 45403  2017-06-30  TIET11                      10.74        21314208.0
# 15883  2017-06-30   EGIE3                      17.24        29171621.0
# 25216  2017-06-30   ITSA4                       4.44        89963145.0
# 1186   2017-06-30   ALSC3                      14.76         7997519.0
# 40507  2017-06-30   SEER3                      20.64        22655182.0
# 41652  2017-06-30   SMLE3                      52.51        42385645.0
# 13638  2017-06-30   CVCB3                      31.70        24414142.0
# 1222   2017-06-30  ALUP11                      13.21        12727737.0
# 43521  2017-06-30  TAEE11                      11.16        44275536.0
# 32346  2017-06-30   NATU3                      12.19        47490205.0
# 28661  2017-06-30   MAGG3                      36.08        20927981.0
# 36071  2017-06-30   POSI3                       2.73         1666233.0
# 11876  2017-06-30   CSAN3                       7.19        40026849.0
# 48438  2017-06-30   VALE3                      18.08       137450466.0
# 6803   2017-06-30   CCRO3                      13.23        68782712.0
#
#         ebit_ev      roic   retorno  ranking_ev_ebit  ranking_roic  \
# 46656  0.688026  0.439928  0.085271              1.0           2.0
# 5114   0.217985  0.277918  0.091013              6.0           5.0
# 16577  0.439335  0.158306  0.015435              3.5          15.5
# 16299  0.439335  0.158306  0.084372              3.5          15.5
# 9262   0.172029  0.156184  0.021028              9.0          17.0
# 45403  0.120248  0.174229  0.029795             22.0          12.0
# 15883  0.106889  0.188912  0.031903             27.0          10.0
# 25216  0.124505  0.154357  0.024775             20.0          18.0
# 1186   0.100269  0.211149  0.114499             30.0           8.0
# 40507  0.097003  0.214553  0.044574             33.0           7.0
# 41652  0.089506  0.495244  0.077890             39.0           1.0
# 13638  0.096999  0.276086  0.100631             34.0           6.0
# 1222   0.144883  0.124716  0.013626             12.0          29.0
# 43521  0.115611  0.145997  0.052867             23.0          22.0
# 32346  0.092906  0.199089 -0.025431             37.0           9.0
# 28661  0.129777  0.119178 -0.051552             16.0          32.0
# 36071  0.235166  0.097333  0.194139              5.0          43.0
# 11876  0.126813  0.116864  0.044506             18.0          33.0
# 48438  0.147280  0.103727  0.079646             10.5          41.5
# 6803   0.097873  0.148122  0.010582             32.0          20.0
#
#        ranking_final
# 46656            1.0
# 5114             2.0
# 16577            3.5
# 16299            3.5
# 9262             5.0
# 45403            6.0
# 15883            7.0
# 25216            8.5
# 1186             8.5
# 40507           11.0
# 41652           11.0
# 13638           11.0
# 1222            13.0
# 43521           14.0
# 32346           15.0
# 28661           16.5
# 36071           16.5
# 11876           18.0
# 48438           20.5
# 6803            20.5

# %% [markdown]
# # Passo 6: Criar  as carteiras.

# %%
dados_empresas = dados_empresas[dados_empresas['ranking_final'] <= 10]

# %% [markdown]
# # Passo 7: Calcular a rentabilidade por carteira.

# %%
rentabilidade_por_carteiras = dados_empresas.groupby('data')['retorno'].mean()
rentabilidade_por_carteiras = rentabilidade_por_carteiras.to_frame()

# %% [markdown]
# # Passo 8: Calcular a rentabilidade do modelo.

# %%
rentabilidade_por_carteiras['Magic Formula'] = (rentabilidade_por_carteiras['retorno'] + 1).cumprod() - 1

rentabilidade_por_carteiras = rentabilidade_por_carteiras.shift(1)

rentabilidade_por_carteiras = rentabilidade_por_carteiras.dropna()

# %% [markdown]
# # Passo 9: Calcular a rentabilidade do ibovespa no mesmo período.

# %%
ibov = pd.read_csv('ibov.csv')

retornos_ibov = ibov['fechamento'].pct_change().dropna()
retorno_acum_ibov = (1 + retornos_ibov).cumprod() - 1
rentabilidade_por_carteiras['Ibovespa'] = retorno_acum_ibov.values
rentabilidade_por_carteiras = rentabilidade_por_carteiras.drop('retorno', axis = 1)

# %% [markdown]
# # Passo 10: Analisar os resultados.

# %%
qs.extend_pandas()
rentabilidade_por_carteiras.index = pd.to_datetime(rentabilidade_por_carteiras.index)

rentabilidade_por_carteiras['Magic Formula'].plot_monthly_heatmap()
rentabilidade_por_carteiras['Ibovespa'].plot_monthly_heatmap()

# %%
rentabilidade_por_carteiras.plot(figsize = (7, 4))
# Out:
# <Axes: xlabel='data'>

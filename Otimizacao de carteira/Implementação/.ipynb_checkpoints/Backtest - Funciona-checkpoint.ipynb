# %%
import bt
import matplotlib.ticker as mtick
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
carteira = ["ALUP11", "BBSE3", "BRAP4", "CMIG4", "CPFE3", "IVVB11", "PRIO3", "CPLE6", "QETH11"]

carteira = [acao + ".SA" for acao in carteira]

# %%
# fetch some data
data = bt.get(carteira, start='2010-01-01', end='2024-10-31')
print(data.head())
# Out:
#                             alup11sa    bbse3sa    brap4sa   cmig4sa  \
# Date
# 2021-08-04 00:00:00+00:00  19.939295  16.279198  21.058464  4.140536
# 2021-08-05 00:00:00+00:00  19.947233  16.097221  19.982784  4.073867
# 2021-08-06 00:00:00+00:00  19.891649  16.150301  19.913832  4.112465
# 2021-08-09 00:00:00+00:00  19.907526  16.446009  19.756617  4.130009
# 2021-08-10 00:00:00+00:00  19.732836  16.301947  19.646292  4.056323
#
#                              cpfe3sa    ivvb11sa    prio3sa   cple6sa  \
# Date
# 2021-08-04 00:00:00+00:00  19.748270  248.729996  17.272257  4.846509
# 2021-08-05 00:00:00+00:00  19.263037  251.300003  17.242306  4.877087
# 2021-08-06 00:00:00+00:00  19.270737  253.500000  17.441984  5.007041
# 2021-08-09 00:00:00+00:00  19.386271  252.729996  17.551809  5.106417
# 2021-08-10 00:00:00+00:00  19.101290  250.800003  18.689980  5.014686
#
#                            qeth11sa
# Date
# 2021-08-04 00:00:00+00:00     10.47
# 2021-08-05 00:00:00+00:00     10.90
# 2021-08-06 00:00:00+00:00     11.45
# 2021-08-09 00:00:00+00:00     12.30
# 2021-08-10 00:00:00+00:00     12.10

# %%
# criando a estratégia
s = bt.Strategy('Carteira', [bt.algos.RunMonthly(),
                       bt.algos.SelectAll(),
                       bt.algos.WeighEqually(),
                       bt.algos.Rebalance()])

# %%
# criando o backtest e rodando ele
test = bt.Backtest(s, data)
res = bt.run(test)
# Out:
# 100%|██████████| 1/1 [00:00<00:00,  5.70it/s]

# %%
#comando para permitir que os gráficos sejam mostrados

plt.ioff()

# %%
# plotando a curva de rentabilidade da carteira
res.plot();

plt.show()

# %%
# ok and how does the return distribution look like?
res.plot_histogram()

plt.show()

# %%
# and just to make sure everything went along as planned, let's plot the security weights over time
res.plot_security_weights()

plt.show()

# %%
# ok and what about some stats?
res.display()
# Out:
# Stat                 s1
# -------------------  ----------
# Start                2021-08-03
# End                  2024-10-30
# Risk-free rate       0.00%
#
# Total Return         94.61%
# Daily Sharpe         1.41
# Daily Sortino        2.40
# CAGR                 22.80%
# Max Drawdown         -15.11%
# Calmar Ratio         1.51
#
# MTD                  -0.47%
# 3m                   0.63%
# 6m                   9.04%
# YTD                  10.63%
# 1Y                   26.78%
# 3Y (ann.)            19.77%
# 5Y (ann.)            -
# 10Y (ann.)           -
# Since Incep. (ann.)  22.80%
#
# Daily Sharpe         1.41
# Daily Sortino        2.40
# Daily Mean (ann.)    21.88%
# Daily Vol (ann.)     15.54%
# Daily Skew           -0.24
# Daily Kurt           0.85
# Best Day             3.40%
# Worst Day            -4.34%
#
# Monthly Sharpe       1.33
# Monthly Sortino      2.58
# Monthly Mean (ann.)  20.77%
# Monthly Vol (ann.)   15.60%
# Monthly Skew         -0.43
# Monthly Kurt         1.38
# Best Month           11.73%
# Worst Month          -11.76%
#
# Yearly Sharpe        2.39
# Yearly Sortino       inf
# Yearly Mean          19.45%
# Yearly Vol           8.15%
# Yearly Skew          -0.85
# Yearly Kurt          -
# Best Year            26.69%
# Worst Year           10.63%
#
# Avg. Drawdown        -2.47%
# Avg. Drawdown Days   17.60
# Avg. Up Month        4.11%
# Avg. Down Month      -2.84%
# Win Year %           100.00%
# Win 12m %            100.00%
